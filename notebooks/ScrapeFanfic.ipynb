# %%
from fanfiction import *

# %%
scraper = Scraper()
metadata = scraper.scrape_story_metadata('10900429')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0494ab661c91> in <module>
#       1 scraper = Scraper()
# ----> 2 metadata = scraper.scrape_story_metadata('10900429')
#
# ~/Documents/GitHub/fanfiction/fanfiction/scraper.py in scrape_story_metadata(self, story_id)
#      61         print(soup)
#      62         pre_story_links = soup.find(id='pre_story_links').find_all('a')
# ---> 63         author_id = int(re.search(r"var userid = (.*);", str(soup)).groups()[0]);
#      64         title = re.search(r"var title = (.*);", str(soup)).groups()[0];
#      65         title = unquote_plus(title)[1:-1]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
test = 123
print(f'{test}')
# Out:
# 123

# %%
import time, re, requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
url = '{0}/s/{1}'.format('http://fanfiction.net/', '10900429')

# selenium set up to get around CloudFlare protection
wd = webdriver.Chrome()
wd.get(url)
page_source = wd.page_source
print(page_source)
wd.close()

# populating tables
soup = BeautifulSoup(page_source, "lxml")
# Out:
# <html class="wf-loading wf-verdana-n4-loading"><head>
# <meta charset="utf-8">
# <meta name="ROBOTS" content="NOARCHIVE">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="format-detection" content="telephone=no">
# <meta name="apple-itunes-app" content="app-id=1192753879">
# <link href="//ff74.b-cdn.net" rel="preconnect">
# <link href="//adservice.google.com" rel="preconnect">
# <link href="//googleads.g.doubleclick.net" rel="preconnect"><meta name="google-site-verification" content="azVIufmnM70GVsbIzGiT1xm8Au0WPBFf0rtJ-puqSQM"><meta name="viewport" content="width=device-width"><link rel="canonical" href="//www.fanfiction.net/s/10900429/1/Rogue">
# <title>Rogue Chapter 1: A Misunderstood Soul, an attack on titan/進撃の巨人 fanfic | FanFiction</title>
# <link rel="shortcut icon" href="/static/images/favicon_2010_site.ico">
# <link rel="icon" type="image/png" href="/static/images/favicon_2010_site.png">
# ...

# %%
pre_story_links = soup.find(id='pre_story_links').find_all('a')
author_id = int(re.search(r"var userid = (.*);", str(soup)).groups()[0]);
title = re.search(r"var title = (.*);", str(soup)).groups()[0];
metadata_div = soup.find(id='profile_top')
times = metadata_div.find_all(attrs={'data-xutime':True})
metadata_text = metadata_div.find(class_='xgray xcontrast_txt').text
metadata_parts = metadata_text.split('-')

# %%
metadata_text
# Out:
# 'Rated: Fiction T - English - Fantasy - Eren Y., Mikasa A., Armin A. - Chapters: 27 - Words: 877,112 - Reviews: 1,016 - Favs: 2,796 - Follows: 2,406 - Updated: Jan 1, 2020 - Published: Dec 19, 2014 - id: 10900429 '
